# %% [markdown]
# # WeatherPy
# ----

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 637

# %%
base_url = "http://api.openweathermap.org/data/2.5/weather?"
url = f"{base_url}units=imperial&appid={weather_api_key}&q="

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
import json
import pprint
response = requests.get(url+city).json()
pprint.pprint(response)
# Out:
# {'base': 'stations',
#  'clouds': {'all': 9},
#  'cod': 200,
#  'coord': {'lat': -30.18, 'lon': -50.21},
#  'dt': 1592771115,
#  'id': 3466165,
#  'main': {'feels_like': 72.37,
#           'grnd_level': 1012,
#           'humidity': 66,
#           'pressure': 1013,
#           'sea_level': 1013,
#           'temp': 73.9,
#           'temp_max': 73.9,
#           'temp_min': 73.9},
#  'name': 'Cidreira',
#  'sys': {'country': 'BR', 'sunrise': 1592734608, 'sunset': 1592771316},
#  'timezone': -10800,
#  'weather': [{'description': 'clear sky',
#               'icon': '01d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 274, 'speed': 9.78}}

# %%
name = []
cloudiness = []
country=[]
date = []
humidity = []
lat = []
lng = []
max_temp = []
wind_speed = []

print('''Beginning Data Retrieval
-----------------------------''')

# initial count method for both processing and set records
processing_record = 1
set_record = 1

for c, city in enumerate(cities):
    
    # if the count number divided by 50 with remainder equals zero, and the count number is greater than 50
    if (c % 50 == 0 and c>50):
        
        # set record increased by 1
        set_record += 1
        
        # processing_record start from zero
        processing_record = 0 
    
    try:
        weather = requests.get(url + city).json()
        
        #Insert data into lists
        name.append(weather["name"])
        cloudiness.append(weather["clouds"]["all"])
        country.append(weather["sys"]["country"])
        date.append(weather["dt"])
        humidity.append(weather["main"]["humidity"])
        lat.append(weather["coord"]["lat"])
        lng.append(weather["coord"]["lon"])
        max_temp.append(weather["main"]["temp_max"])
        wind_speed.append(weather["wind"]["speed"])
        print(f"Processing Record {processing_record} of set {set_record} | {city}")
        processing_record += 1
        
    except :
        print("City not found. Skipping...")
    pass

print('''-----------------------------
Data Retrieval Complete
-----------------------------''')
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of set 1 | bembereke
# Processing Record 2 of set 1 | clyde river
# Processing Record 3 of set 1 | kruisfontein
# Processing Record 4 of set 1 | richards bay
# Processing Record 5 of set 1 | saint-pierre
# Processing Record 6 of set 1 | barrow
# Processing Record 7 of set 1 | birao
# City not found. Skipping...
# Processing Record 8 of set 1 | oranjestad
# Processing Record 9 of set 1 | vila velha
# Processing Record 10 of set 1 | hithadhoo
# Processing Record 11 of set 1 | narsaq
# Processing Record 12 of set 1 | butaritari
# Processing Record 13 of set 1 | mishelevka
# Processing Record 14 of set 1 | sao joao da barra
# Processing Record 15 of set 1 | jamestown
# Processing Record 16 of set 1 | fez
# Processing Record 17 of set 1 | qaanaaq
# Processing Record 18 of set 1 | coquimbo
# Processing Record 19 of set 1 | atuona
# Processing Record 20 of set 1 | vaini
# Processing Record 21 of set 1 | yining
# Processing Record 22 of set 1 | nador
# Processing Record 23 of set 1 | luderitz
# Processing Record 24 of set 1 | ponta do sol
# Processing Record 25 of set 1 | rawson
# City not found. Skipping...
# Processing Record 26 of set 1 | tabou
# Processing Record 27 of set 1 | saint-philippe
# Processing Record 28 of set 1 | port keats
# Processing Record 29 of set 1 | yellowknife
# Processing Record 30 of set 1 | busselton
# Processing Record 31 of set 1 | bengkulu
# Processing Record 32 of set 1 | jamame
# Processing Record 33 of set 1 | albany
# Processing Record 34 of set 1 | dikson
# Processing Record 35 of set 1 | rikitea
# Processing Record 36 of set 1 | kavieng
# Processing Record 37 of set 1 | teknaf
# Processing Record 38 of set 1 | castro
# Processing Record 39 of set 1 | debre birhan
# Processing Record 40 of set 1 | tasiilaq
# Processing Record 41 of set 1 | tual
# Processing Record 42 of set 1 | bathsheba
# Processing Record 43 of set 1 | petropavlovka
# Processing Record 44 of set 1 | kapaa
# Processing Record 45 of set 1 | belaya gora
# Processing Record 46 of set 1 | cape town
# Processing Record 47 of set 1 | vestmannaeyjar
# Processing Record 48 of set 1 | lebu
# Processing Record 49 of set 1 | matara
# Processing Record 50 of set 1 | nadym
# Processing Record 51 of set 1 | evensk
# Processing Record 52 of set 1 | severo-kurilsk
# Processing Record 53 of set 1 | punta arenas
# Processing Record 54 of set 1 | vostok
# Processing Record 55 of set 1 | nalut
# Processing Record 56 of set 1 | pisco
# Processing Record 57 of set 1 | port alfred
# Processing Record 58 of set 1 | lago da pedra
# Processing Record 59 of set 1 | basco
# Processing Record 60 of set 1 | ushuaia
# Processing Record 61 of set 1 | cabedelo
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 62 of set 1 | pevek
# Processing Record 63 of set 1 | nabire
# Processing Record 64 of set 1 | damaturu
# Processing Record 65 of set 1 | guiong
# Processing Record 66 of set 1 | saskylakh
# Processing Record 67 of set 1 | nouadhibou
# Processing Record 68 of set 1 | esperance
# Processing Record 69 of set 1 | sao jose da coroa grande
# City not found. Skipping...
# Processing Record 70 of set 1 | port lincoln
# Processing Record 71 of set 1 | comodoro rivadavia
# Processing Record 72 of set 1 | nishihara
# Processing Record 73 of set 1 | lubin
# City not found. Skipping...
# Processing Record 74 of set 1 | saint-leu
# Processing Record 75 of set 1 | ishurdi
# Processing Record 76 of set 1 | katsuura
# Processing Record 77 of set 1 | san patricio
# Processing Record 78 of set 1 | tucupita
# Processing Record 79 of set 1 | ribeira grande
# Processing Record 80 of set 1 | acapulco
# Processing Record 81 of set 1 | mana
# City not found. Skipping...
# Processing Record 82 of set 1 | hobart
# Processing Record 83 of set 1 | tokmak
# Processing Record 84 of set 1 | egvekinot
# Processing Record 85 of set 1 | hilo
# Processing Record 86 of set 1 | mackay
# Processing Record 87 of set 1 | fiumicino
# Processing Record 88 of set 1 | guerrero negro
# Processing Record 89 of set 1 | puerto ayora
# Processing Record 90 of set 1 | bonavista
# Processing Record 91 of set 1 | port elizabeth
# Processing Record 92 of set 1 | udachnyy
# Processing Record 93 of set 1 | hasaki
# Processing Record 0 of set 2 | saint-augustin
# Processing Record 1 of set 2 | caravelas
# Processing Record 2 of set 2 | lensk
# Processing Record 3 of set 2 | the valley
# Processing Record 4 of set 2 | mataura
# Processing Record 5 of set 2 | kieta
# Processing Record 6 of set 2 | vao
# Processing Record 7 of set 2 | hermanus
# Processing Record 8 of set 2 | tuktoyaktuk
# Processing Record 9 of set 2 | carhuaz
# Processing Record 10 of set 2 | douglas
# Processing Record 11 of set 2 | faanui
# Processing Record 12 of set 2 | verkhovye
# Processing Record 13 of set 2 | avarua
# Processing Record 14 of set 2 | carballo
# Processing Record 15 of set 2 | khorramshahr
# Processing Record 16 of set 2 | digha
# Processing Record 17 of set 2 | camopi
# Processing Record 18 of set 2 | bethel
# Processing Record 19 of set 2 | tuatapere
# Processing Record 20 of set 2 | ilulissat
# Processing Record 21 of set 2 | coihaique
# City not found. Skipping...
# Processing Record 22 of set 2 | amroli
# Processing Record 23 of set 2 | chokurdakh
# City not found. Skipping...
# Processing Record 24 of set 2 | sao pedro do sul
# Processing Record 25 of set 2 | buin
# Processing Record 26 of set 2 | pimentel
# Processing Record 27 of set 2 | amahai
# Processing Record 28 of set 2 | polunochnoye
# Processing Record 29 of set 2 | broken hill
# Processing Record 30 of set 2 | chake chake
# Processing Record 31 of set 2 | oranjemund
# Processing Record 32 of set 2 | isoka
# Processing Record 33 of set 2 | uyo
# Processing Record 34 of set 2 | grindavik
# Processing Record 35 of set 2 | celestun
# Processing Record 36 of set 2 | brasileia
# Processing Record 37 of set 2 | arraial do cabo
# Processing Record 38 of set 2 | nieuw amsterdam
# Processing Record 39 of set 2 | port macquarie
# Processing Record 40 of set 2 | thompson
# Processing Record 41 of set 2 | moirang
# Processing Record 42 of set 2 | kaitangata
# City not found. Skipping...
# Processing Record 43 of set 2 | broome
# Processing Record 44 of set 2 | kolokani
# Processing Record 45 of set 2 | gananoque
# Processing Record 46 of set 2 | meulaboh
# Processing Record 0 of set 3 | cherskiy
# Processing Record 1 of set 3 | provideniya
# Processing Record 2 of set 3 | san andres
# Processing Record 3 of set 3 | new norfolk
# City not found. Skipping...
# Processing Record 4 of set 3 | jinchang
# Processing Record 5 of set 3 | osa
# Processing Record 6 of set 3 | burkburnett
# Processing Record 7 of set 3 | hofn
# Processing Record 8 of set 3 | nanakuli
# Processing Record 9 of set 3 | lorengau
# Processing Record 10 of set 3 | codrington
# Processing Record 11 of set 3 | jumla
# Processing Record 12 of set 3 | flin flon
# Processing Record 13 of set 3 | ugoofaaru
# Processing Record 14 of set 3 | upernavik
# Processing Record 15 of set 3 | torbay
# Processing Record 16 of set 3 | nikolskoye
# Processing Record 17 of set 3 | dingle
# Processing Record 18 of set 3 | barinas
# Processing Record 19 of set 3 | canyon lake
# Processing Record 20 of set 3 | abu samrah
# Processing Record 21 of set 3 | haines junction
# Processing Record 22 of set 3 | wiarton
# Processing Record 23 of set 3 | maracas
# Processing Record 24 of set 3 | houma
# Processing Record 25 of set 3 | saint-gaudens
# Processing Record 26 of set 3 | yanai
# Processing Record 27 of set 3 | pacific grove
# Processing Record 28 of set 3 | isangel
# Processing Record 29 of set 3 | buchanan
# Processing Record 30 of set 3 | pandan
# Processing Record 31 of set 3 | olafsvik
# Processing Record 32 of set 3 | harer
# Processing Record 33 of set 3 | trinidad
# Processing Record 34 of set 3 | abu kamal
# Processing Record 35 of set 3 | itarema
# Processing Record 36 of set 3 | asyut
# Processing Record 37 of set 3 | kristiinankaupunki
# City not found. Skipping...
# Processing Record 38 of set 3 | zeya
# Processing Record 39 of set 3 | mahebourg
# Processing Record 40 of set 3 | barabinsk
# Processing Record 41 of set 3 | chuy
# Processing Record 42 of set 3 | san cristobal
# Processing Record 43 of set 3 | shimanovsk
# Processing Record 44 of set 3 | ancud
# Processing Record 45 of set 3 | cidreira
# Processing Record 46 of set 3 | faya
# Processing Record 47 of set 3 | constitucion
# City not found. Skipping...
# Processing Record 0 of set 4 | maues
# Processing Record 1 of set 4 | flinders
# Processing Record 2 of set 4 | caieiras
# Processing Record 3 of set 4 | peleduy
# Processing Record 4 of set 4 | lakes entrance
# Processing Record 5 of set 4 | lompoc
# Processing Record 6 of set 4 | mount gambier
# Processing Record 7 of set 4 | bluff
# Processing Record 8 of set 4 | souillac
# Processing Record 9 of set 4 | kahului
# Processing Record 10 of set 4 | walvis bay
# City not found. Skipping...
# Processing Record 11 of set 4 | rudbar
# Processing Record 12 of set 4 | kincardine
# Processing Record 13 of set 4 | katobu
# Processing Record 14 of set 4 | hovd
# Processing Record 15 of set 4 | santo domingo
# Processing Record 16 of set 4 | vila do maio
# Processing Record 17 of set 4 | longyearbyen
# Processing Record 18 of set 4 | belyy
# City not found. Skipping...
# Processing Record 19 of set 4 | praia
# Processing Record 20 of set 4 | tiarei
# Processing Record 21 of set 4 | la asuncion
# Processing Record 22 of set 4 | kodiak
# Processing Record 23 of set 4 | bredasdorp
# Processing Record 24 of set 4 | luwuk
# Processing Record 25 of set 4 | chaman
# Processing Record 26 of set 4 | tautira
# Processing Record 27 of set 4 | dunmanway
# Processing Record 28 of set 4 | okhotsk
# Processing Record 29 of set 4 | olinda
# Processing Record 30 of set 4 | deputatskiy
# Processing Record 31 of set 4 | bar harbor
# Processing Record 32 of set 4 | lakhtar
# Processing Record 33 of set 4 | hobyo
# Processing Record 34 of set 4 | khatanga
# Processing Record 35 of set 4 | talnakh
# Processing Record 36 of set 4 | doha
# Processing Record 37 of set 4 | izumo
# Processing Record 38 of set 4 | longkou
# Processing Record 39 of set 4 | owando
# Processing Record 40 of set 4 | tottori
# Processing Record 41 of set 4 | eyl
# Processing Record 42 of set 4 | mar del plata
# Processing Record 43 of set 4 | ahipara
# Processing Record 44 of set 4 | asosa
# Processing Record 45 of set 4 | havoysund
# Processing Record 46 of set 4 | sao filipe
# Processing Record 0 of set 5 | te anau
# Processing Record 1 of set 5 | norman wells
# Processing Record 2 of set 5 | westport
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 3 of set 5 | virginia beach
# Processing Record 4 of set 5 | dehloran
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 5 of set 5 | itaituba
# Processing Record 6 of set 5 | kaniama
# Processing Record 7 of set 5 | oktyabrskoye
# Processing Record 8 of set 5 | vadlapudi
# Processing Record 9 of set 5 | east london
# Processing Record 10 of set 5 | nome
# Processing Record 11 of set 5 | shimoda
# Processing Record 12 of set 5 | salalah
# Processing Record 13 of set 5 | fonte boa
# City not found. Skipping...
# Processing Record 14 of set 5 | ruwi
# Processing Record 15 of set 5 | fortuna
# Processing Record 16 of set 5 | garissa
# Processing Record 17 of set 5 | bendigo
# Processing Record 18 of set 5 | lodeynoye pole
# Processing Record 19 of set 5 | biritiba-mirim
# Processing Record 20 of set 5 | strand
# Processing Record 21 of set 5 | carnarvon
# Processing Record 22 of set 5 | zhezkazgan
# Processing Record 23 of set 5 | shingu
# City not found. Skipping...
# Processing Record 24 of set 5 | sur
# City not found. Skipping...
# Processing Record 25 of set 5 | zhigansk
# City not found. Skipping...
# Processing Record 26 of set 5 | adrar
# Processing Record 27 of set 5 | jacareacanga
# Processing Record 28 of set 5 | qasigiannguit
# Processing Record 29 of set 5 | auce
# City not found. Skipping...
# Processing Record 30 of set 5 | manicore
# Processing Record 31 of set 5 | kasiri
# Processing Record 32 of set 5 | herat
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 33 of set 5 | verkh-usugli
# Processing Record 34 of set 5 | ostrovnoy
# Processing Record 35 of set 5 | kushima
# Processing Record 36 of set 5 | ouango
# Processing Record 0 of set 6 | san policarpo
# Processing Record 1 of set 6 | banjar
# Processing Record 2 of set 6 | altamira
# Processing Record 3 of set 6 | cao bang
# Processing Record 4 of set 6 | turukhansk
# Processing Record 5 of set 6 | presidencia roque saenz pena
# Processing Record 6 of set 6 | casambalangan
# Processing Record 7 of set 6 | jerantut
# Processing Record 8 of set 6 | namatanai
# Processing Record 9 of set 6 | port-cartier
# Processing Record 10 of set 6 | iqaluit
# City not found. Skipping...
# Processing Record 11 of set 6 | vardo
# Processing Record 12 of set 6 | san juan
# Processing Record 13 of set 6 | bambous virieux
# Processing Record 14 of set 6 | college
# Processing Record 15 of set 6 | del rio
# City not found. Skipping...
# Processing Record 16 of set 6 | yar-sale
# Processing Record 17 of set 6 | baykit
# Processing Record 18 of set 6 | klaksvik
# Processing Record 19 of set 6 | alofi
# Processing Record 20 of set 6 | eravur
# Processing Record 21 of set 6 | copiapo
# City not found. Skipping...
# Processing Record 22 of set 6 | porosozero
# Processing Record 23 of set 6 | yulara
# Processing Record 24 of set 6 | jawar
# Processing Record 25 of set 6 | qaqortoq
# Processing Record 26 of set 6 | prince rupert
# Processing Record 27 of set 6 | oga
# Processing Record 28 of set 6 | paragominas
# Processing Record 29 of set 6 | airai
# Processing Record 30 of set 6 | muslyumovo
# Processing Record 31 of set 6 | kassiopi
# Processing Record 32 of set 6 | muisne
# Processing Record 33 of set 6 | killybegs
# Processing Record 34 of set 6 | turayf
# Processing Record 35 of set 6 | cape girardeau
# Processing Record 36 of set 6 | oxbow
# Processing Record 37 of set 6 | cabo san lucas
# Processing Record 38 of set 6 | jiwani
# Processing Record 39 of set 6 | tahe
# Processing Record 40 of set 6 | banda aceh
# Processing Record 41 of set 6 | georgetown
# Processing Record 42 of set 6 | dzhankoy
# Processing Record 43 of set 6 | harrow
# Processing Record 44 of set 6 | tiksi
# Processing Record 45 of set 6 | sorland
# Processing Record 46 of set 6 | saldanha
# Processing Record 0 of set 7 | los llanos de aridane
# Processing Record 1 of set 7 | chilliwack
# Processing Record 2 of set 7 | ushtobe
# Processing Record 3 of set 7 | kragero
# Processing Record 4 of set 7 | sola
# Processing Record 5 of set 7 | labuhan
# Processing Record 6 of set 7 | punta de bombon
# Processing Record 7 of set 7 | peniche
# Processing Record 8 of set 7 | noumea
# Processing Record 9 of set 7 | ramhormoz
# Processing Record 10 of set 7 | saint-joseph
# Processing Record 11 of set 7 | terrace
# Processing Record 12 of set 7 | sahawar
# Processing Record 13 of set 7 | tilichiki
# City not found. Skipping...
# Processing Record 14 of set 7 | soller
# Processing Record 15 of set 7 | zhangye
# Processing Record 16 of set 7 | lagoa
# Processing Record 17 of set 7 | guozhen
# Processing Record 18 of set 7 | dunedin
# Processing Record 19 of set 7 | victoria
# Processing Record 20 of set 7 | san quintin
# Processing Record 21 of set 7 | jalu
# Processing Record 22 of set 7 | wanning
# City not found. Skipping...
# Processing Record 23 of set 7 | saint george
# Processing Record 24 of set 7 | linqiong
# Processing Record 25 of set 7 | diamantino
# Processing Record 26 of set 7 | popondetta
# Processing Record 27 of set 7 | dano
# Processing Record 28 of set 7 | fukue
# Processing Record 29 of set 7 | aquiraz
# Processing Record 30 of set 7 | leningradskiy
# Processing Record 31 of set 7 | ypsonas
# Processing Record 32 of set 7 | purpe
# Processing Record 33 of set 7 | batagay-alyta
# Processing Record 34 of set 7 | mungaa
# Processing Record 35 of set 7 | valley city
# Processing Record 36 of set 7 | bubaque
# Processing Record 37 of set 7 | sri aman
# Processing Record 38 of set 7 | san jeronimo
# Processing Record 39 of set 7 | solnechnyy
# Processing Record 40 of set 7 | bowen
# Processing Record 41 of set 7 | syracuse
# Processing Record 42 of set 7 | valparaiso
# City not found. Skipping...
# Processing Record 43 of set 7 | wawa
# Processing Record 44 of set 7 | genhe
# Processing Record 45 of set 7 | svetlyy
# Processing Record 46 of set 7 | antalaha
# Processing Record 0 of set 8 | natal
# Processing Record 1 of set 8 | mukhen
# Processing Record 2 of set 8 | verkhoyansk
# Processing Record 3 of set 8 | victor harbor
# Processing Record 4 of set 8 | ryabovo
# Processing Record 5 of set 8 | wajir
# Processing Record 6 of set 8 | mogadishu
# Processing Record 7 of set 8 | yerbogachen
# Processing Record 8 of set 8 | salinopolis
# Processing Record 9 of set 8 | pula
# Processing Record 10 of set 8 | half moon bay
# Processing Record 11 of set 8 | bacolod
# Processing Record 12 of set 8 | machali
# Processing Record 13 of set 8 | nago
# Processing Record 14 of set 8 | ulaanbaatar
# Processing Record 15 of set 8 | ketchikan
# Processing Record 16 of set 8 | taltal
# City not found. Skipping...
# Processing Record 17 of set 8 | tarrega
# Processing Record 18 of set 8 | tooele
# Processing Record 19 of set 8 | miracema do tocantins
# Processing Record 20 of set 8 | sitka
# City not found. Skipping...
# Processing Record 21 of set 8 | dwarka
# Processing Record 22 of set 8 | sao felix do xingu
# Processing Record 23 of set 8 | gat
# Processing Record 24 of set 8 | nemuro
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 25 of set 8 | moga
# Processing Record 26 of set 8 | nan
# Processing Record 27 of set 8 | yuancheng
# Processing Record 28 of set 8 | gigmoto
# Processing Record 29 of set 8 | nivala
# Processing Record 30 of set 8 | pangnirtung
# Processing Record 31 of set 8 | avera
# Processing Record 32 of set 8 | aykhal
# Processing Record 33 of set 8 | olavarria
# Processing Record 34 of set 8 | kauhajoki
# Processing Record 35 of set 8 | alta floresta
# Processing Record 36 of set 8 | mount darwin
# Processing Record 37 of set 8 | tshikapa
# Processing Record 38 of set 8 | sabha
# Processing Record 39 of set 8 | bang krathum
# Processing Record 40 of set 8 | ursulo galvan
# Processing Record 41 of set 8 | muros
# Processing Record 42 of set 8 | paamiut
# Processing Record 43 of set 8 | zyryanka
# Processing Record 44 of set 8 | tongchuan
# Processing Record 45 of set 8 | mitsamiouli
# Processing Record 0 of set 9 | rundu
# Processing Record 1 of set 9 | nanortalik
# Processing Record 2 of set 9 | mvuma
# Processing Record 3 of set 9 | brownsville
# Processing Record 4 of set 9 | uyuni
# Processing Record 5 of set 9 | ambulu
# Processing Record 6 of set 9 | kokopo
# Processing Record 7 of set 9 | north bend
# Processing Record 8 of set 9 | saryg-sep
# Processing Record 9 of set 9 | naze
# Processing Record 10 of set 9 | lata
# Processing Record 11 of set 9 | mancio lima
# Processing Record 12 of set 9 | sulangan
# Processing Record 13 of set 9 | imbituba
# Processing Record 14 of set 9 | guabito
# Processing Record 15 of set 9 | luanda
# Processing Record 16 of set 9 | santa cruz
# Processing Record 17 of set 9 | tyup
# Processing Record 18 of set 9 | vyazemskiy
# Processing Record 19 of set 9 | raudeberg
# Processing Record 20 of set 9 | byron bay
# Processing Record 21 of set 9 | hami
# Processing Record 22 of set 9 | manzanillo
# Processing Record 23 of set 9 | edd
# Processing Record 24 of set 9 | malakal
# Processing Record 25 of set 9 | loubomo
# Processing Record 26 of set 9 | karratha
# City not found. Skipping...
# Processing Record 27 of set 9 | forestville
# Processing Record 28 of set 9 | atikokan
# Processing Record 29 of set 9 | sao gabriel da cachoeira
# Processing Record 30 of set 9 | kuusamo
# Processing Record 31 of set 9 | songjianghe
# Processing Record 32 of set 9 | portland
# Processing Record 33 of set 9 | kikuyu
# City not found. Skipping...
# Processing Record 34 of set 9 | laurel
# Processing Record 35 of set 9 | barentu
# Processing Record 36 of set 9 | husavik
# Processing Record 37 of set 9 | pitiquito
# Processing Record 38 of set 9 | midland
# Processing Record 39 of set 9 | tiznit
# Processing Record 40 of set 9 | lithgow
# Processing Record 41 of set 9 | vitim
# Processing Record 42 of set 9 | rozkishne
# Processing Record 43 of set 9 | nioro
# Processing Record 44 of set 9 | guadalupe victoria
# Processing Record 45 of set 9 | envira
# Processing Record 46 of set 9 | altay
# Processing Record 47 of set 9 | hamilton
# Processing Record 0 of set 10 | vila franca do campo
# Processing Record 1 of set 10 | ifanadiana
# Processing Record 2 of set 10 | anadyr
# Processing Record 3 of set 10 | agucadoura
# Processing Record 4 of set 10 | puerto madryn
# Processing Record 5 of set 10 | bandarbeyla
# City not found. Skipping...
# Processing Record 6 of set 10 | arona
# Processing Record 7 of set 10 | mount isa
# Processing Record 8 of set 10 | kavaratti
# Processing Record 9 of set 10 | labuan
# Processing Record 10 of set 10 | ambon
# Processing Record 11 of set 10 | andenes
# Processing Record 12 of set 10 | kansanshi
# Processing Record 13 of set 10 | paciran
# Processing Record 14 of set 10 | ahuimanu
# Processing Record 15 of set 10 | cuamba
# Processing Record 16 of set 10 | gladstone
# Processing Record 17 of set 10 | merke
# Processing Record 18 of set 10 | tucurui
# Processing Record 19 of set 10 | greece
# Processing Record 20 of set 10 | sinnamary
# City not found. Skipping...
# Processing Record 21 of set 10 | khonsa
# Processing Record 22 of set 10 | gorom-gorom
# Processing Record 23 of set 10 | lar
# Processing Record 24 of set 10 | vasalemma
# Processing Record 25 of set 10 | zavodoukovsk
# Processing Record 26 of set 10 | honningsvag
# Processing Record 27 of set 10 | ha giang
# Processing Record 28 of set 10 | namibe
# Processing Record 29 of set 10 | amapa
# Processing Record 30 of set 10 | sarh
# Processing Record 31 of set 10 | porbandar
# Processing Record 32 of set 10 | nijar
# Processing Record 33 of set 10 | cayenne
# Processing Record 34 of set 10 | margate
# Processing Record 35 of set 10 | freeport
# Processing Record 36 of set 10 | chara
# Processing Record 37 of set 10 | makasar
# Processing Record 38 of set 10 | maldonado
# Processing Record 39 of set 10 | ponta delgada
# City not found. Skipping...
# Processing Record 40 of set 10 | tila
# Processing Record 41 of set 10 | mildura
# Processing Record 42 of set 10 | beatrice
# Processing Record 43 of set 10 | manggar
# Processing Record 44 of set 10 | koslan
# Processing Record 45 of set 10 | sistranda
# Processing Record 46 of set 10 | kutum
# Processing Record 0 of set 11 | grand-lahou
# Processing Record 1 of set 11 | burnie
# Processing Record 2 of set 11 | piacabucu
# Processing Record 3 of set 11 | vredendal
# Processing Record 4 of set 11 | guanica
# Processing Record 5 of set 11 | khartoum
# Processing Record 6 of set 11 | asau
# Processing Record 7 of set 11 | falmouth
# Processing Record 8 of set 11 | mangrol
# City not found. Skipping...
# Processing Record 9 of set 11 | porto torres
# City not found. Skipping...
# Processing Record 10 of set 11 | goleniow
# Processing Record 11 of set 11 | la libertad
# Processing Record 12 of set 11 | mendi
# City not found. Skipping...
# Processing Record 13 of set 11 | saint anthony
# Processing Record 14 of set 11 | mabini
# Processing Record 15 of set 11 | livingstone
# Processing Record 16 of set 11 | golden
# Processing Record 17 of set 11 | balkhash
# Processing Record 18 of set 11 | alice springs
# Processing Record 19 of set 11 | oussouye
# Processing Record 20 of set 11 | nhulunbuy
# Processing Record 21 of set 11 | phetchaburi
# Processing Record 22 of set 11 | arman
# Processing Record 23 of set 11 | ankazoabo
# Processing Record 24 of set 11 | ust-tsilma
# City not found. Skipping...
# Processing Record 25 of set 11 | angoche
# Processing Record 26 of set 11 | sioux lookout
# Processing Record 27 of set 11 | barvinkove
# Processing Record 28 of set 11 | cubara
# Processing Record 29 of set 11 | kaduqli
# Processing Record 30 of set 11 | marrakesh
# Processing Record 31 of set 11 | olga
# City not found. Skipping...
# Processing Record 32 of set 11 | milovice
# Processing Record 33 of set 11 | ulladulla
# City not found. Skipping...
# Processing Record 34 of set 11 | komsomolskiy
# Processing Record 35 of set 11 | itaqui
# Processing Record 36 of set 11 | tagbac
# City not found. Skipping...
# Processing Record 37 of set 11 | quatre cocos
# Processing Record 38 of set 11 | malinovskiy
# Processing Record 39 of set 11 | puerto princesa
# Processing Record 40 of set 11 | moshny
# Processing Record 41 of set 11 | ginda
# Processing Record 42 of set 11 | monterey
# Processing Record 0 of set 12 | laranjeiras do sul
# City not found. Skipping...
# Processing Record 1 of set 12 | pokhara
# Processing Record 2 of set 12 | bantry
# Processing Record 3 of set 12 | harper
# Processing Record 4 of set 12 | torata
# Processing Record 5 of set 12 | kuruman
# Processing Record 6 of set 12 | plettenberg bay
# Processing Record 7 of set 12 | conde
# Processing Record 8 of set 12 | lewistown
# Processing Record 9 of set 12 | middletown
# Processing Record 10 of set 12 | algiers
# Processing Record 11 of set 12 | aksu
# Processing Record 12 of set 12 | la paz
# Processing Record 13 of set 12 | port-gentil
# Processing Record 14 of set 12 | kabale
# Processing Record 15 of set 12 | okha
# Processing Record 16 of set 12 | svobodnyy
# Processing Record 17 of set 12 | kingman
# Processing Record 18 of set 12 | merrill
# Processing Record 19 of set 12 | touros
# City not found. Skipping...
# Processing Record 20 of set 12 | necochea
# Processing Record 21 of set 12 | campo formoso
# Processing Record 22 of set 12 | micheweni
# City not found. Skipping...
# Processing Record 23 of set 12 | wattegama
# City not found. Skipping...
# Processing Record 24 of set 12 | beringovskiy
# Processing Record 25 of set 12 | japura
# Processing Record 26 of set 12 | dire
# Processing Record 27 of set 12 | woodward
# Processing Record 28 of set 12 | marawi
# Processing Record 29 of set 12 | pathein
# Processing Record 30 of set 12 | serenje
# Processing Record 31 of set 12 | mastic beach
# Processing Record 32 of set 12 | fort nelson
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# Export the city-data to a csv file 
#city_data.to_csv("city_data.csv")

# %%
city_data = pd.DataFrame({"City":name,
                         "Cloudiness":cloudiness,
                         "Country":country,
                         "Date":date,
                         "Humidity":humidity,
                         "Lat":lat,
                         "Lng":lng,
                         "Max Temp":max_temp,
                         "Wind Speed":wind_speed})
city_data.count()
# Out:
# City          583
# Cloudiness    583
# Country       583
# Date          583
# Humidity      583
# Lat           583
# Lng           583
# Max Temp      583
# Wind Speed    583
# dtype: int64

# %%
#Display the DataFrame
city_data.head()
# Out:
#            City  Cloudiness Country        Date  Humidity    Lat    Lng  \
# 0     Bembèrèkè          78      BJ  1592771396        78  10.23   2.66
# 1   Clyde River           1      CA  1592771127        81  70.47 -68.59
# 2  Kruisfontein           0      ZA  1592771129        88 -34.00  24.73
# 3  Richards Bay           0      ZA  1592771396        64 -28.78  32.04
# 4  Saint-Pierre          20      RE  1592771396        82 -21.34  55.48
#
#    Max Temp  Wind Speed
# 0     77.97        9.10
# 1     44.60        5.82
# 2     53.78        5.77
# 3     62.29        6.46
# 4     66.20        4.70

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
# Plot scatter points to visualize relationship between latitude and temperatue 
plt.scatter(lat, max_temp, marker ="o",edgecolor="black" )
plt.grid(True)

plt.xlabel("Latitude")
plt.ylabel("Max Temperature")
plt.title("City Latitude vs. Max Temperature")

plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
# Plot scatter points to visualize relationship between latitude and humidity 
plt.scatter(lat, humidity, marker ="o",edgecolor="black" )
plt.grid(True)

plt.xlabel("Latitude")
plt.ylabel("Humidity % ")
plt.title("City Latitude vs. Humidity")

plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
# Plot scatter points to visualize relationship between latitude and cloudiness 
plt.scatter(lat, cloudiness, marker ="o",edgecolor="black" )
plt.grid(True)

plt.xlabel("Latitude")
plt.ylabel("Cloudiness % ")
plt.title("City Latitude vs. Cloudiness")

plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Plot scatter points to visualize relationship between latitude and wind speed 
plt.scatter(lat, wind_speed, marker ="o",edgecolor="black" )
plt.grid(True)

plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph) ")
plt.title("City Latitude vs. Wind Speed")

plt.show()

# %% [markdown]
# ## Linear Regression

# %%
# Create a function to create Linear Regression plots

def linear_regression(x_value, y_value):
    
    (slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_values, y_values)

    # Get regression values
    regress_values = x_values * slope + intercept
    #print(regress_values)

    # Create line equation string
    line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
    print(line_eq)


    # Create Plot
    plt.scatter(x_values,y_values)
    plt.plot(x_values,regress_values,"r-")

    # Label plot and annotate the line equation
    plt.xlabel('Latitude')
    plt.ylabel('Temperature')
    plt.annotate(line_eq,(20,15),fontsize=15,color="red")

    # Print r square value
    print(f"The r-squared is: {rvalue}")

    # Show plot
    plt.show()

# %%
# Create Northern and Southern Hemisphere DataFrames
north_hemi_df = city_data.loc[(city_data["Lat"] >= 0)]
south_hemi_df = city_data.loc[(city_data["Lat"] < 0)]

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_value = north_hemi_df["Lat"]
y_value = north_hemi_df["Max Temp"]

from scipy.stats import linregress

(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_values, y_values)

# Get regression values
regress_values = x_values * slope + intercept
#print(regress_values)

# Create line equation string
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
print(line_eq)


# Create Plot
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")

# Label plot and annotate the line equation
plt.xlabel('Latitude')
plt.ylabel('Temperature')
plt.annotate(line_eq,(20,15),fontsize=15,color="red")

# Print r square value
print(f"The r-squared is: {rvalue}")

# Show plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-51-fdbfa723f3c5> in <module>
#       4 from scipy.stats import linregress
#       5
# ----> 6 (slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_values, y_values)
#       7
#       8 # Get regression values
#
# NameError: name 'stats' is not defined

# %%
# Out:
# The r-squared is: -0.8151657406810827

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Out:
# The r-squared is: 0.760263355051646

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Out:
# The r-squared is: 0.10358336015746494

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Out:
# The r-squared is: 0.14689473425583055

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Out:
# The r-squared is: -0.08733547918934018

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Out:
# The r-squared is: 0.21881426893991618

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Out:
# The r-squared is: 0.1071382774388479

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Out:
# The r-squared is: -0.322483077139538
